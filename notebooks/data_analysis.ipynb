# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/uniprot_2026/processed_data/features_master.parquet')

# %%
df.head()
# Out:
#     accession  entry_name raw_feature_type    label  start   end  length  \
# 0  A0A068B6Q6  CA18_CONBE       Propeptide   PROPEP    1.0  20.0    20.0
# 1  A0A068B6Q6  CA18_CONBE          Peptide  PEPTIDE   21.0  36.0    16.0
# 2  A0A068B6Q6  CA18_CONBE             Site     Site   29.0  29.0     1.0
# 3  A0A068B6Q6  CA18_CONBE             Site     Site   30.0  30.0     1.0
# 4  A0A068B6Q6  CA18_CONBE             Site     Site   31.0  31.0     1.0
#
#        feature_sequence                                description  \
# 0  PDGRNAAAKAFDLITPTVRK
# 1      GCCSNPACILNNPNQC                            Conotoxin Bt1.8
# 2                     I             Important for binding to nAChR
# 3                     L  Moderately important for binding to nAChR
# 4                     N             Important for binding to nAChR
#
#   start_modifier  ... evidence_sources evidence_ids  pubmed_ids  \
# 0        OUTSIDE  ...      [UniProtKB]     [Q86RB2]          []
# ...

# %%
df.columns
# Out:
# Index(['accession', 'entry_name', 'raw_feature_type', 'label', 'start', 'end',
#        'length', 'feature_sequence', 'description', 'start_modifier',
#        'end_modifier', 'evidence_codes', 'evidence_sources', 'evidence_ids',
#        'pubmed_ids', 'has_sorting_prorule', 'is_target_type',
#        'basic_drop_reason', 'is_valid_basic', 'deeppeptide_extra_drop_reason',
#        'drop_reason', 'is_valid_for_training'],
#       dtype='object')
